# %% [markdown]
# # SRFREW-EDA

# %%
import os 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import altair as alt

alt.data_transformers.enable("vegafusion");

# %%
assignments = pd.read_csv(os.path.join("data", "assignments.csv"))
discussion_topics = pd.read_csv(os.path.join("data", "discussion_topics.csv"))
discussions = pd.read_csv(os.path.join("data", "discussions.csv"))
enrollments = pd.read_csv(os.path.join("data", "enrollments.csv"))
files = pd.read_csv(os.path.join("data", "files.csv"))
gradebook = pd.read_csv(os.path.join("data", "gradebook.csv"))
module_items = pd.read_csv(os.path.join("data", "module_items.csv"))
navigation_events = pd.read_csv(os.path.join("data", "navigation_events.csv"))
pages = pd.read_csv(os.path.join("data", "pages.csv"))

# %%
gradebook.loc[:, gradebook.columns != "Student"] = gradebook.loc[:, gradebook.columns != "Student"].apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2368, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Manual Posting"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[239], line 1
# ----> 1 gradebook.loc[:, gradebook.columns != "Student"] = gradebook.loc[:, gradebook.columns != "Student"].apply(pd.to_numeric)
#
# File ~/miniconda3/envs/571/lib/python3.10/site-packages/pandas/core/frame.py:10037, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10025 from pandas.core.apply import frame_apply
#   10027 op = frame_apply(
#   10028     self,
#   10029     func=func,
#    (...)
#   10035     kwargs=kwargs,
#   10036 )
# > 10037 return op.apply().__finalize__(self, method="apply")
#
# File ~/miniconda3/envs/571/lib/python3.10/site-packages/pandas/core/apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File ~/miniconda3/envs/571/lib/python3.10/site-packages/pandas/core/apply.py:963, in FrameApply.apply_standard(self)
#     962 def apply_standard(self):
# --> 963     results, res_index = self.apply_series_generator()
#     965     # wrap results
#     966     return self.wrap_results(results, res_index)
#
# File ~/miniconda3/envs/571/lib/python3.10/site-packages/pandas/core/apply.py:979, in FrameApply.apply_series_generator(self)
#     976 with option_context("mode.chained_assignment", None):
#     977     for i, v in enumerate(series_gen):
#     978         # ignore SettingWithCopy here in case the user mutates
# --> 979         results[i] = self.func(v, *self.args, **self.kwargs)
#     980         if isinstance(results[i], ABCSeries):
#     981             # If we have a view on v, we need to make a copy because
#     982             #  series_generator will swap out the underlying data
#     983             results[i] = results[i].copy(deep=False)
#
# File ~/miniconda3/envs/571/lib/python3.10/site-packages/pandas/core/tools/numeric.py:222, in to_numeric(arg, errors, downcast, dtype_backend)
#     220 coerce_numeric = errors not in ("ignore", "raise")
#     221 try:
# --> 222     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa: E501
#     223         values,
#     224         set(),
#     225         coerce_numeric=coerce_numeric,
#     226         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     227         or isinstance(values_dtype, StringDtype),
#     228     )
#     229 except (ValueError, TypeError):
#     230     if errors == "raise":
#
# File lib.pyx:2410, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Manual Posting" at position 0

# %%
# gradebook 
gradebook.drop(index=[0,1], inplace=True)
gradebook.loc[:, gradebook.columns != "Student"] = gradebook.loc[:, gradebook.columns != "Student"].apply(pd.to_numeric)

# drop strange/na columns
navigation_events.drop(columns=["ed_app", "type", "action", "course_offering_id", "statement_type", "statement_version", "event__object_type", "event__object_extensions_asset_subtype", "event__object_extensions_entity_id", "event__referrer", "event__extensions_request_url", "event__attachment_type"], inplace=True)

# drop learners that are not enrolled in the course
navigation_events = navigation_events.iloc[np.in1d(navigation_events.actor_id, enrollments.user_id), :]
navigation_events = navigation_events.query("actor_id != 'LEARNER_48'")
                       
navigation_events.event_time = pd.to_datetime(navigation_events.event_time, format='ISO8601').dt.normalize()

# %% [markdown]
# ID MAP:
# `object_id` maps to:
# - `discussion_topics.id`
# - `discussions.discussion_topic_id`
# - `assignments.id`
# - `files.id`
# - `pages.id`
#
#
# Does NOT map to:
# - anything in `module_items`
# - anything in `gradebook`

# %%
object_id_map = pd.concat([discussion_topics.loc[:,["id", "title"]],
           assignments.loc[:,["id", "name"]].rename({"name": "title"}, inplace=True),
           files.loc[:,["id", "filename_masked"]].rename({"filename_masked": "title"}, inplace=True),
           pages.loc[:,["id", "title"]]
          ])
# Out:
#                                   id  \
# 0   132f3fab56d60839d727b966a76c1b1e
# 1   e1f90c16c123e0f96b2af7d94a1c335c
# 2   7c9e39571ad00fe24282e5b5366d7563
# 3   c916612763c04832d8e7b9e89deb7d2a
# 4   bb62cd396b9a8a94ecef6b5d1c4f8ad1
# ..                               ...
# 87  972196dd128aeb62a66f5c02b897e7dd
# 88  9ee9a2cacefb8be58dde2a381617e0ad
# 89  0790ff605875f7393f9fde5c50c3eae4
# 90  47cc5ac28d341bcc8e175c649974a314
# 91  5dbb1884e151f5ac0e7e5dbbe2897ae5
#
#                                                 title
# 0                       Assignment 1 Discussion forum
# 1                                  Introduce yourself
# 2   Discussion 2: Reflect on rationales for eLearning
# 3              Discussion 1: The meaning of eLearning
# 4                        Discussion 3: Funding issues
# ..                                                ...
# 87              [wikipage] Assignment 2 Group sign up
# 88     Wikipage Assignment 2 Group Sign Up (Optional)
# 89   [wikipage] Assignment 3 Group sign up (optional)
# 90                                    Your Instructor
# 91             Your responses (eLearning terminology)
#
# [111 rows x 2 columns]

# %%
alt.Chart(navigation_events).mark_bar().encode(
    x = alt.X("event_time:T"), 
    y = "count()",
    color = "event__object_extensions_asset_type"
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(navigation_events).mark_bar().encode(
    x = alt.X("actor_id"), 
    y = "count()",
    color = "event__object_extensions_asset_type"
)
# Out:
# alt.Chart(...)

# %%
a = pd.DataFrame(navigation_events.groupby(["actor_id", "event__object_extensions_asset_type"]).count()["id"]).unstack()
a.columns = a.columns.droplevel()
a["total_clicks"] = np.sum(a, axis=1)

b = pd.merge(a, gradebook, how="left", right_on="Student", left_index=True)
b.describe()
# Out:
#        assignment   attachment  discussion_topic   wiki_page  total_clicks
# count   33.000000    33.000000         33.000000   33.000000     33.000000
# mean    83.000000   982.575758        179.151515  334.333333   1579.060606
# std     41.953099   443.609769        130.637409  163.203031    717.507314
# min     26.000000   267.000000         37.000000   56.000000    511.000000
# 25%     60.000000   680.000000         78.000000  204.000000   1092.000000
# 50%     73.000000   898.000000        159.000000  321.000000   1548.000000
# 75%     97.000000  1204.000000        213.000000  444.000000   1901.000000
# max    198.000000  2360.000000        642.000000  748.000000   3687.000000

# %%
alt.Chart(b).mark_point().encode(
    x = alt.X(alt.repeat(), type="quantitative"),
    y = "Current Score"
).properties(width = 150, height = 150).repeat(['assignment', 'attachment', 'discussion_topic', 'wiki_page', 'total_clicks'])
# Out:
# alt.RepeatChart(...)

# %%
pd.merge(navigation_events.groupby("actor_id").count()["id"],  pd.to_numeric(gradebook.set_index("Student")["Current Score"]), how="left", left_index=True, right_index=True)
# Out:
#               id  Current Score
# actor_id
# LEARNER_1   1132           80.9
# LEARNER_10  1096           78.4
# LEARNER_11  2188           84.3
# LEARNER_12  1901           81.2
# LEARNER_13  3687           85.5
# LEARNER_14  1548           84.4
# LEARNER_15   998           76.2
# LEARNER_16  1661           82.0
# LEARNER_17  1892           65.7
# LEARNER_18  1350           69.7
# LEARNER_19  1667           85.2
# LEARNER_2   1981           84.6
# LEARNER_20  1352           69.7
# LEARNER_21   957           78.5
# LEARNER_23  1868           89.2
# LEARNER_24  1801           86.4
# LEARNER_25   540           87.3
# LEARNER_26   650           87.5
# LEARNER_27  1355           73.0
# LEARNER_29  2222           85.7
# LEARNER_3   1901           89.0
# LEARNER_30  1364           78.3
# LEARNER_31   836           77.9
# LEARNER_33   511           72.1
# LEARNER_34   673           81.3
# LEARNER_35   903           79.1
# LEARNER_36  1377           70.9
# LEARNER_37  1092           82.3
# LEARNER_4   1819           82.9
# LEARNER_5   1611           88.0
# LEARNER_6   2801           92.2
# LEARNER_7   2497           87.3
# LEARNER_8   2878           83.6

# %%
gradebook.set_index("Student")
# Out:
#            Assignment 1 (c81f04547a95da2a7b88054ef491b7c4)  \
# Student
# LEARNER_4                                               88
# LEARNER_10                                              88
# LEARNER_34                                              90
# LEARNER_16                                              88
# LEARNER_7                                               92
# LEARNER_30                                              77
# LEARNER_15                                              90
# LEARNER_19                                              90
# LEARNER_36                                              56
# LEARNER_8                                               90
# LEARNER_20                                              82
# LEARNER_13                                              88
# LEARNER_37                                              94
# LEARNER_17                                              80
# LEARNER_23                                              91
# LEARNER_14                                              95
# LEARNER_21                                              71
# LEARNER_29                                              89
# LEARNER_35                                              92
# LEARNER_11                                              90
# LEARNER_24                                              95
# LEARNER_1                                               79
# LEARNER_31                                              78
# LEARNER_6                                               94
# LEARNER_2                                               93
# LEARNER_12                                              86
# LEARNER_3                                               94
# LEARNER_48                                              69
# LEARNER_33                                              79
# LEARNER_27                                              84
# LEARNER_25                                              93
# LEARNER_26                                              90
# LEARNER_5                                               91
# LEARNER_18                                              73
#
#            Assignment 2 (a4dc11e7e79361fc5886a9078aac66b8)  \
# Student
# LEARNER_4                                               76
# LEARNER_10                                              72
# LEARNER_34                                              78
# LEARNER_16                                              71
# LEARNER_7                                               83
# LEARNER_30                                              89
# LEARNER_15                                              79
# LEARNER_19                                              83
# LEARNER_36                                              84
# LEARNER_8                                               88
# LEARNER_20                                              82
# LEARNER_13                                              86
# LEARNER_37                                              82
# LEARNER_17                                              65
# LEARNER_23                                              87
# LEARNER_14                                              92
# LEARNER_21                                              87
# LEARNER_29                                              90
# LEARNER_35                                              72
# LEARNER_11                                              79
# LEARNER_24                                              90
# LEARNER_1                                               84
# LEARNER_31                                              84
# LEARNER_6                                               94
# LEARNER_2                                               85
# LEARNER_12                                              87
# LEARNER_3                                               92
# LEARNER_48                                             NaN
# LEARNER_33                                              87
# LEARNER_27                                              85
# LEARNER_25                                              88
# LEARNER_26                                              83
# LEARNER_5                                               82
# LEARNER_18                                              73
#
#            Assignment 3 (option A) (811d93ea379b5cdd5a19f1b5dbab88cd)  \
# Student
# LEARNER_4                                                  75
# LEARNER_10                                                 74
# LEARNER_34                                                 73
# LEARNER_16                                                NaN
# LEARNER_7                                                 NaN
# LEARNER_30                                                NaN
# LEARNER_15                                                 75
# LEARNER_19                                                NaN
# LEARNER_36                                                 75
# LEARNER_8                                                  74
# LEARNER_20                                                 59
# LEARNER_13                                                 87
# LEARNER_37                                                 83
# LEARNER_17                                                 74
# LEARNER_23                                                 83
# LEARNER_14                                                NaN
# LEARNER_21                                                 84
# LEARNER_29                                                 83
# LEARNER_35                                                NaN
# LEARNER_11                                                NaN
# LEARNER_24                                                NaN
# LEARNER_1                                                 NaN
# LEARNER_31                                                 77
# LEARNER_6                                                 NaN
# LEARNER_2                                                 NaN
# LEARNER_12                                                NaN
# LEARNER_3                                                 NaN
# LEARNER_48                                                NaN
# LEARNER_33                                                NaN
# LEARNER_27                                                 69
# LEARNER_25                                                 81
# LEARNER_26                                                NaN
# LEARNER_5                                                  84
# LEARNER_18                                                NaN
#
#            Assignment 3 (option B) (df8d1f1ff3f48fdc24a278b40c5f45cc)  \
# Student
# LEARNER_4                                                 NaN
# LEARNER_10                                                NaN
# LEARNER_34                                                NaN
# LEARNER_16                                                NaN
# LEARNER_7                                                 NaN
# LEARNER_30                                                NaN
# LEARNER_15                                                NaN
# LEARNER_19                                                NaN
# LEARNER_36                                                NaN
# LEARNER_8                                                 NaN
# LEARNER_20                                                NaN
# LEARNER_13                                                NaN
# LEARNER_37                                                NaN
# LEARNER_17                                                NaN
# LEARNER_23                                                NaN
# LEARNER_14                                                 86
# LEARNER_21                                                NaN
# LEARNER_29                                                NaN
# LEARNER_35                                                 77
# LEARNER_11                                                NaN
# LEARNER_24                                                NaN
# LEARNER_1                                                 NaN
# LEARNER_31                                                NaN
# LEARNER_6                                                  84
# LEARNER_2                                                 NaN
# LEARNER_12                                                NaN
# LEARNER_3                                                 NaN
# LEARNER_48                                                NaN
# LEARNER_33                                                NaN
# LEARNER_27                                                NaN
# LEARNER_25                                                NaN
# LEARNER_26                                                NaN
# LEARNER_5                                                 NaN
# LEARNER_18                                                NaN
#
#            Assignment 3 (option C) (bb971b36c1578cede00150acda89aa99)  \
# Student
# LEARNER_4                                                 NaN
# LEARNER_10                                                NaN
# LEARNER_34                                                NaN
# LEARNER_16                                                 77
# LEARNER_7                                                  80
# LEARNER_30                                                 74
# LEARNER_15                                                NaN
# LEARNER_19                                                 81
# LEARNER_36                                                NaN
# LEARNER_8                                                 NaN
# LEARNER_20                                                NaN
# LEARNER_13                                                NaN
# LEARNER_37                                                NaN
# LEARNER_17                                                NaN
# LEARNER_23                                                NaN
# LEARNER_14                                                NaN
# LEARNER_21                                                NaN
# LEARNER_29                                                NaN
# LEARNER_35                                                NaN
# LEARNER_11                                                 82
# LEARNER_24                                                 78
# LEARNER_1                                                  73
# LEARNER_31                                                NaN
# LEARNER_6                                                 NaN
# LEARNER_2                                                 NaN
# LEARNER_12                                                 73
# LEARNER_3                                                  82
# LEARNER_48                                                NaN
# LEARNER_33                                                 74
# LEARNER_27                                                NaN
# LEARNER_25                                                NaN
# LEARNER_26                                                 82
# LEARNER_5                                                 NaN
# LEARNER_18                                                 74
#
#            Assignment 3 (option D) (f1ad954cd2cddda6e17f6fc225d1aa3e)  \
# Student
# LEARNER_4                                                 NaN
# LEARNER_10                                                NaN
# LEARNER_34                                                NaN
# LEARNER_16                                                NaN
# LEARNER_7                                                 NaN
# LEARNER_30                                                NaN
# LEARNER_15                                                NaN
# LEARNER_19                                                NaN
# LEARNER_36                                                NaN
# LEARNER_8                                                 NaN
# LEARNER_20                                                NaN
# LEARNER_13                                                NaN
# LEARNER_37                                                NaN
# LEARNER_17                                                NaN
# LEARNER_23                                                NaN
# LEARNER_14                                                NaN
# LEARNER_21                                                NaN
# LEARNER_29                                                NaN
# LEARNER_35                                                NaN
# LEARNER_11                                                NaN
# LEARNER_24                                                NaN
# LEARNER_1                                                 NaN
# LEARNER_31                                                NaN
# LEARNER_6                                                 NaN
# LEARNER_2                                                  95
# LEARNER_12                                                NaN
# LEARNER_3                                                 NaN
# LEARNER_48                                                NaN
# LEARNER_33                                                NaN
# LEARNER_27                                                NaN
# LEARNER_25                                                NaN
# LEARNER_26                                                NaN
# LEARNER_5                                                 NaN
# LEARNER_18                                                NaN
#
#            Participation grade: Formative (not included in final grade) (5965e0b0c712861d0efdd9be54572114)  \
# Student
# LEARNER_4                                                  10
# LEARNER_10                                                8.5
# LEARNER_34                                                  9
# LEARNER_16                                                 10
# LEARNER_7                                                  10
# LEARNER_30                                                  7
# LEARNER_15                                                  6
# LEARNER_19                                                  9
# LEARNER_36                                                  6
# LEARNER_8                                                 8.5
# LEARNER_20                                                5.5
# LEARNER_13                                                  8
# LEARNER_37                                                  7
# LEARNER_17                                                  4
# LEARNER_23                                                 10
# LEARNER_14                                                  6
# LEARNER_21                                                6.5
# LEARNER_29                                                  8
# LEARNER_35                                                  8
# LEARNER_11                                                  9
# LEARNER_24                                                8.5
# LEARNER_1                                                   9
# LEARNER_31                                                  7
# LEARNER_6                                                  10
# LEARNER_2                                                   6
# LEARNER_12                                                  8
# LEARNER_3                                                   9
# LEARNER_48                                                NaN
# LEARNER_33                                                  4
# LEARNER_27                                                  5
# LEARNER_25                                                  9
# LEARNER_26                                                 10
# LEARNER_5                                                  10
# LEARNER_18                                                5.5
#
#            Assignment 1 Current Score Assignment 2 Current Score  \
# Student
# LEARNER_4                          88                         76
# LEARNER_10                         88                         72
# LEARNER_34                         90                         78
# LEARNER_16                         88                         71
# LEARNER_7                          92                         83
# LEARNER_30                         77                         89
# LEARNER_15                         90                         79
# LEARNER_19                         90                         83
# LEARNER_36                         56                         84
# LEARNER_8                          90                         88
# LEARNER_20                         82                         82
# LEARNER_13                         88                         86
# LEARNER_37                         94                         82
# LEARNER_17                         80                         65
# LEARNER_23                         91                         87
# LEARNER_14                         95                         92
# LEARNER_21                         71                         87
# LEARNER_29                         89                         90
# LEARNER_35                         92                         72
# LEARNER_11                         90                         79
# LEARNER_24                         95                         90
# LEARNER_1                          79                         84
# LEARNER_31                         78                         84
# LEARNER_6                          94                         94
# LEARNER_2                          93                         85
# LEARNER_12                         86                         87
# LEARNER_3                          94                         92
# LEARNER_48                         69                        NaN
# LEARNER_33                         79                         87
# LEARNER_27                         84                         85
# LEARNER_25                         93                         88
# LEARNER_26                         90                         83
# LEARNER_5                          91                         82
# LEARNER_18                         73                         73
#
#            Assignment 3 Current Score  \
# Student
# LEARNER_4                          75
# LEARNER_10                         74
# LEARNER_34                         73
# LEARNER_16                         77
# LEARNER_7                          80
# LEARNER_30                         74
# LEARNER_15                         75
# LEARNER_19                         81
# LEARNER_36                         75
# LEARNER_8                          74
# LEARNER_20                         59
# LEARNER_13                         87
# LEARNER_37                         83
# LEARNER_17                         74
# LEARNER_23                         83
# LEARNER_14                         86
# LEARNER_21                         84
# LEARNER_29                         83
# LEARNER_35                         77
# LEARNER_11                         82
# LEARNER_24                         78
# LEARNER_1                          73
# LEARNER_31                         77
# LEARNER_6                          84
# LEARNER_2                          95
# LEARNER_12                         73
# LEARNER_3                          82
# LEARNER_48                        NaN
# LEARNER_33                         74
# LEARNER_27                         69
# LEARNER_25                         81
# LEARNER_26                         82
# LEARNER_5                          84
# LEARNER_18                         74
#
#            Participation & engagement Current Score Current Score
# Student
# LEARNER_4                                       100          82.9
# LEARNER_10                                       85          78.4
# LEARNER_34                                       90          81.3
# LEARNER_16                                      100            82
# LEARNER_7                                       100          87.3
# LEARNER_30                                       70          78.3
# LEARNER_15                                       60          76.2
# LEARNER_19                                       90          85.2
# LEARNER_36                                       60          70.9
# LEARNER_8                                        85          83.6
# LEARNER_20                                       55          69.7
# LEARNER_13                                       80          85.5
# LEARNER_37                                       70          82.3
# LEARNER_17                                       40          65.7
# LEARNER_23                                      100          89.2
# LEARNER_14                                       60          84.4
# LEARNER_21                                       65          78.5
# LEARNER_29                                       80          85.7
# LEARNER_35                                       80          79.1
# LEARNER_11                                       90          84.3
# LEARNER_24                                       85          86.4
# LEARNER_1                                        90          80.9
# LEARNER_31                                       70          77.9
# LEARNER_6                                       100          92.2
# LEARNER_2                                        60          84.6
# LEARNER_12                                       80          81.2
# LEARNER_3                                        90            89
# LEARNER_48                                      NaN          13.8
# LEARNER_33                                       40          72.1
# LEARNER_27                                       50            73
# LEARNER_25                                       90          87.3
# LEARNER_26                                      100          87.5
# LEARNER_5                                       100            88
# LEARNER_18                                       55          69.7

# %%
navigation_events.groupby("actor_id").count()["id"]
# Out:
# actor_id
# LEARNER_1     1132
# LEARNER_10    1096
# LEARNER_11    2188
# LEARNER_12    1901
# LEARNER_13    3687
# LEARNER_14    1548
# LEARNER_15     998
# LEARNER_16    1661
# LEARNER_17    1892
# LEARNER_18    1350
# LEARNER_19    1667
# LEARNER_2     1981
# LEARNER_20    1352
# LEARNER_21     957
# LEARNER_23    1868
# LEARNER_24    1801
# LEARNER_25     540
# LEARNER_26     650
# LEARNER_27    1355
# LEARNER_29    2222
# LEARNER_3     1901
# LEARNER_30    1364
# LEARNER_31     836
# LEARNER_33     511
# LEARNER_34     673
# LEARNER_35     903
# LEARNER_36    1377
# LEARNER_37    1092
# LEARNER_4     1819
# LEARNER_48       1
# LEARNER_5     1611
# LEARNER_6     2801
# LEARNER_7     2497
# LEARNER_8     2878
# Name: id, dtype: int64
